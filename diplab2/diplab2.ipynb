# %%
pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2

# %% [markdown]
# # task 1

# %%
#absolute path
img=cv2.imread(r"C:\Users\Student\Desktop\abc.jfif")
#same folder
img2=cv2.imread(r"C:\Users\Student\Desktop\lab2\subhome.jfif")
#different folder
img3=cv2.imread(r"C:\Users\Student\Desktop\lab2\images\images.jfif")

# %%
type(img)
# Out:
# numpy.ndarray

# %% [markdown]
# # task 2

# %%
#gives dimensions of img in tuple
#168 no of rows
#275 no of col
#3 no of channels(colors)
img.shape
# Out:
# (183, 275, 3)

# %%
print(img)
# Out:
# [[[125 120  75]
#   [125 120  75]
#   [125 120  75]
#   ...
#   [ 88 182 255]
#   [ 88 182 255]
#   [ 88 182 255]]
#
#  [[125 120  75]
#   [125 120  75]
#   [125 119  76]
#   ...
#   [ 87 182 255]
#   [ 87 182 255]
#   [ 87 182 255]]
#
#  [[125 120  75]
#   [125 119  76]
#   [125 119  76]
#   ...
#   [ 85 183 255]
#   [ 85 183 255]
#   [ 85 183 255]]
#
#  ...
#
#  [[ 23   8   0]
#   [ 23   8   0]
#   [ 23   8   0]
#   ...
#   [ 41  30   2]
#   [ 41  30   2]
#   [ 41  30   2]]
#
#  [[ 24   8   1]
#   [ 24   8   1]
#   [ 24   8   1]
#   ...
#   [ 41  30   2]
#   [ 41  30   2]
#   [ 41  30   2]]
#
#  [[ 26  10   3]
#   [ 26  10   3]
#   [ 26  10   3]
#   ...
#   [ 41  30   2]
#   [ 41  30   2]
#   [ 41  30   2]]]

# %%
#img=cv2.resize(img,(400,400))
#cv2.imshow("image",img)
#cv2.waitKey(0)
#cv2.destroyAllWindows()

# %% [markdown]
# # task 4

# %%
b,r,g=cv2.split(img)
print("red channel matrix\n",r)
print("blue channel matrix\n",b)
print("green channel matrix\n",g)
# Out:
# red channel matrix
#  [[120 120 120 ... 182 182 182]
#  [120 120 119 ... 182 182 182]
#  [120 119 119 ... 183 183 183]
#  ...
#  [  8   8   8 ...  30  30  30]
#  [  8   8   8 ...  30  30  30]
#  [ 10  10  10 ...  30  30  30]]
# blue channel matrix
#  [[125 125 125 ...  88  88  88]
#  [125 125 125 ...  87  87  87]
#  [125 125 125 ...  85  85  85]
#  ...
#  [ 23  23  23 ...  41  41  41]
#  [ 24  24  24 ...  41  41  41]
#  [ 26  26  26 ...  41  41  41]]
# green channel matrix
#  [[ 75  75  75 ... 255 255 255]
#  [ 75  75  76 ... 255 255 255]
#  [ 75  76  76 ... 255 255 255]
#  ...
#  [  0   0   0 ...   2   2   2]
#  [  1   1   1 ...   2   2   2]
#  [  3   3   3 ...   2   2   2]]

# %%
# cv2.imshow('Red Channel', r)
# cv2.imshow('Green Channel', g)
# cv2.imshow('Blue Channel', b)

# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %% [markdown]
# # task 6

# %%
#grayscale formula
grey=0.9*r+0.9*g+0.9*b

# %%
cv2.imshow("all channels",grey)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # task 5

# %%
import pandas as pd
from sklearn.datasets import load_iris

iris = load_iris()
print(iris.DESCR)

df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
df['species'] = iris.target

print(df.head())
# Out:
# .. _iris_dataset:
#
# Iris plants dataset
# --------------------
#
# **Data Set Characteristics:**
#
# :Number of Instances: 150 (50 in each of three classes)
# :Number of Attributes: 4 numeric, predictive attributes and the class
# :Attribute Information:
#     - sepal length in cm
#     - sepal width in cm
#     - petal length in cm
#     - petal width in cm
#     - class:
#             - Iris-Setosa
#             - Iris-Versicolour
#             - Iris-Virginica
#
# :Summary Statistics:
#
# ============== ==== ==== ======= ===== ====================
#                 Min  Max   Mean    SD   Class Correlation
# ============== ==== ==== ======= ===== ====================
# sepal length:   4.3  7.9   5.84   0.83    0.7826
# sepal width:    2.0  4.4   3.05   0.43   -0.4194
# petal length:   1.0  6.9   3.76   1.76    0.9490  (high!)
# petal width:    0.1  2.5   1.20   0.76    0.9565  (high!)
# ============== ==== ==== ======= ===== ====================
#
# ...

# %% [markdown]
# # task 3

# %%
#PIL
from PIL import Image

# %%
img=Image.open(r"C:\Users\Fujitsu T\Desktop\diplab2\images.jpg")
img.show()

# %%
#matplotlib
import matplotlib.pyplot as plt
import matplotlib.image as img

# %%
image=img.imread(r"C:\Users\Fujitsu T\Desktop\diplab2\images.jpg")
plt.imshow(image)
